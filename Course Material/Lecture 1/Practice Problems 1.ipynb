# %% [markdown]
# ## Practice Problems

# %% [markdown]
# **Task 1:** Find and print the area of a circle with radius 12.6 inches. Hint : Make sure to use variables!
#
# <!-- Answer:
# ```
# pi = 3.141
# r = 12.6
# area = pi*(r**2)
# print(area)
# ``` -->

# %% [markdown]
# **Task 2:** Use the area value from the first question as the length of a rectangle and half the area value as the width of the rectangle then find the perimeter of the rectangle, but round down to the nearest whole number. You may leave it in float form (Example: 21.0).
#
# <!-- Answer:
# ```
# length = 498.759249684
# width = length/2
# perimeter = 2*length + 2*width
# print(perimeter)
# ``` -->

# %% [markdown]
# **Task 3:** Make 3 variables where 2 of them are strings and the last one is a boolean.  Comment the boolean variable, then combine the string variables into a new variable called answer, print answer to the screen. Hint : This question might seem lengthy but it is not too bad :)
# <!--
# Answer:
#
# ```
# planet_one = 'saturn'
# # planet_two = 'pluto'
# planet_three = 'earth'
# answer = planet_three + planet_one
# print(answer)
# ``` -->

# %% [markdown]
# **Task 4:** Make 2 new variables called first_name and last_name and make it equal to your first and last name, respectively. Then add your first and last name variables but put a '12' between them and print the result. Your answer should look like 'Rahul12Dani' but with your name.
#
# <!-- Answer:
# ```
# first_name = 'Rahul'
# last_name = 'Dani'
# print(first_name+'12'+last_name)
# ``` -->

# %% [markdown]
# **Task 5:** Make a variable called x and put an integer in it. Then make a new variable called k with the type of x. Then modify x and make it a boolean and make another new variable called b with the new type of x. Check if k and b are equal, print that to the screen.
#
# <!-- Answer:
# ```
# x = 17
# k = type(x)
# x = True
# b = type(x)
# print(k == b)
# ``` -->

# %% [markdown]
# **Task 6 :** Swap the values of two variables. Ex : If x = 5 and y = 12, make x = 12 and y = 5, without saying 'x = 12, y = 5'
