# %% [markdown]
# ## Practice Problems

# %% [markdown]
# **Task 1:** Take 2 numbers as user input and add them.
#
# <!-- Answer:
# ```
# a = input('Enter first number: ')
# b = input('Enter second number: ')
# print('The sum of your numbers is:', int(a)+int(b))
# ``` -->

# %% [markdown]
# **Task 2:** Take a user input value for 'x' variable and then make the new value of x equal to x times 6, then make x equal to the new value squared. Use the count operator.
#
# <!-- Answer:
# ```
# x = input('Enter a number： ')
# x = int(x)
# x *= 6
# x **= 2
# print(x)
# ``` -->

# %% [markdown]
# **Task 3:** Make 2 color variables with your favorite colors. Take a user input for a color and see if that color is either your color 1 or color 2 variable, if so print 'Oh, me too!', otherwise print 'Sorry, we like different colors'.
#
# <!-- Answer:
# ```
# color_one = 'red'
# color_two = 'blue'
# user_color = input('Enter your favorite color here (lowercase): ')
# if(user_color == color_one or user_color == color_two):
#     print('Oh, me too!')
# else:
#     print('Sorry, we like different colors')
# ``` -->

# %% [markdown]
# **Task 4:** Take a user input number, if the number is even then print 'This number is even', otherwise print 'This number is odd'. Hint: Use the modulus (%) operator.
#
# <!-- Answer:
# ```
# num = input('Enter your number here: ')
# num = int(num)
# if(num % 2 == 0):
#     print('This number is even!')
# else:
#     print('This number is odd!')
# ``` -->
